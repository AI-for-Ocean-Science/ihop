# %% [markdown]
# # NMF Test

# %%
# imports
import numpy as np
from matplotlib import pyplot as plt

import seaborn as sns

from NonnegMFPy import nmf

#from ihip.ihop import io as ihop_io
from ihop.hydrolight import loisel23

# %%
# %matplotlib ipympl

# %% [markdown]
# # Load spectra

# %%
X=4
Y=0
ds = loisel23.load_ds(X, Y)

# %%
spec = ds['a'].data
spec.shape
# Out:
# (3320, 81)

# %% [markdown]
# # Cut

# %%
keep = ds.Lambda < 700.

# %%
spec = spec[:,keep]

# %% [markdown]
# # Run it!

# %%
g = nmf.NMF(spec.T, n_components=5)

# %%
chi2, time_used = g.SolveNMF()
# Out:
# Current Chi2=0.0040, Previous Chi2=1.3230, Change=99.7000% @ niters=0
# Current Chi2=0.0001, Previous Chi2=0.0002, Change=12.4266% @ niters=20
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=2.1098% @ niters=40
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.5219% @ niters=60
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.1884% @ niters=80
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0857% @ niters=100
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0378% @ niters=120
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0180% @ niters=140
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0099% @ niters=160
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0099% @ niters=180
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0271% @ niters=200
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0346% @ niters=220
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0187% @ niters=240
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0139% @ niters=260
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0112% @ niters=280
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0094% @ niters=300
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0084% @ niters=320
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0078% @ niters=340
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0076% @ niters=360
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0078% @ niters=380
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0083% @ niters=400
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0090% @ niters=420
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0100% @ niters=440
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0113% @ niters=460
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0127% @ niters=480
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0145% @ niters=500
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0165% @ niters=520
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0187% @ niters=540
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0212% @ niters=560
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0240% @ niters=580
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0271% @ niters=600
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0305% @ niters=620
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0342% @ niters=640
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0382% @ niters=660
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0426% @ niters=680
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0473% @ niters=700
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0523% @ niters=720
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0577% @ niters=740
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0634% @ niters=760
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0695% @ niters=780
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0759% @ niters=800
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0827% @ niters=820
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0897% @ niters=840
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.0971% @ niters=860
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.1048% @ niters=880
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.1126% @ niters=900
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.1206% @ niters=920
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.1285% @ niters=940
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.1363% @ niters=960
# Current Chi2=0.0000, Previous Chi2=0.0000, Change=0.1438% @ niters=980
# Iteration in re-initialization reaches maximum number = 1000
# Took 0.090 minutes to reach current solution.

# %%
g.W.shape
# Out:
# (70, 5)

# %% [markdown]
# # Plot the basis set

# %%
M = g.W.T
wave = ds.Lambda.data[keep]
#
fig = plt.figure(figsize=(7,5))

plt.clf()
ax = plt.gca()
for ss in range(5):
    ax.plot(wave,M[ss], label=r'$\xi_'+f'{ss}'+'$')
#ax.plot(wave,M[1], label=r'$\xi_2$')
#ax.plot(wave,M[2], label=r'$\xi_3$')
#
ax.set_xlabel('Wavelength (nm)')
ax.set_ylabel('Basis vector')
ax.legend()
#
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Reconstruct one

# %%
g.H.shape, g.W.shape
# Out:
# ((5, 3320), (70, 5))

# %%
g.H[:,0]
# Out:
# array([0.01076157, 0.00491633, 0.06268624, 0.10876674, 0.06676776])

# %%
idx = 1000
recon = np.dot(g.H[:,idx], g.W.T)
recon.shape
# Out:
# (70,)

# %% [markdown]
# ## Plot

# %%
fig = plt.figure(figsize=(7,5))

plt.clf()
ax = plt.gca()
#for ss in range(5):
#    ax.plot(wave,M[ss], label=r'$\xi_'+f'{ss}'+'$')
ax.plot(wave,spec[idx, :], 'o', label=r'Orig')
ax.plot(wave,recon, label=r'Recon')
#ax.plot(wave,M[2], label=r'$\xi_3$')
#
ax.set_xlabel('Wavelength (nm)')
ax.set_ylabel('a')
ax.legend()
#
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure(figsize=(7,5))

plt.clf()
ax = plt.gca()
#for ss in range(5):
#    ax.plot(wave,M[ss], label=r'$\xi_'+f'{ss}'+'$')
ax.plot(wave,(spec[idx, :]-recon)/spec[idx,:], 'o')
#ax.plot(wave,recon, label=r'Recon')
#ax.plot(wave,M[2], label=r'$\xi_3$')
#
ax.set_xlabel('Wavelength (nm)')
ax.set_ylabel('Residual')
#ax.legend()
#
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
